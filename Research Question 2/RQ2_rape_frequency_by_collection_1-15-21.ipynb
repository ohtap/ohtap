# %%
import os
import pandas as pd
from collections import defaultdict

# %%
'''
DESCRIPTION-------
Example code for reading NVivo coded content from an NVivo extract into a pandas dataframe. 
Here we read in two files, one containing an extract of all NVivo coding except errors (everything_but_errors_12-22-20.xls), and 
another containing only the error coding (errors_12-22-20.xls). The code itself is trivial and the important points are contained in the NOTES.
NOTES-------
1) dependencies: the df.read_excel() in pandas uses the xlrd package internally, so you need to pip or conda install xlrd
2) need to export the NVivo extract as an .xls file 
  - NOT .xlsx, because for some reason xlrd now only supports the older .xls file type
  - NOT .csv because some cell values (description, coded text, maybe others) can contain commas and it is a hassle to work around this
3) df.read_excel() cannot read the .xls file as directly exported from NVivo (NVivo's exported .xls file is malformed according to .read_excel()'s requirements)
So as a workaround, you can "repair" NVivo's .xls file by doing the following (but the .xls files contained in ohtap/NVivo_output/data are already repaired, so 
no need to do this step unless you are working with .xls files you exported yourself from NVivo):
   -open up the .xls file that was exported from NVivo in some spreadsheet software (I used mac's Numbers application, but Google Sheets or Excel would probably work too)
   -re-export the opened file as another .xls file (which will now be well-formed for .read_excel()). In the Numbers application, what you do precisely is
     + navigate to File -> Export To -> Excel...
     + under "Advanced Options" change file type to .xls
     + in the Excel Worksheets field, select "One Per Table" and nothing else (in particular, unselect "Include a summary worksheet" if that was selected by default")
     + click next and save the repaired file where you want
'''



#Set up directory structure however you want. Here the 'repaired' (as described above) .xls files are assumed to reside in the directory ./data/nvivo_content
NVIVO_CONTENT_FP = os.path.join(".", "data", "nvivo_content")
NOT_ERRORS_FP = os.path.join(NVIVO_CONTENT_FP, "everything_but_errors_12-22-20.xls")
ERRORS_FP = os.path.join(NVIVO_CONTENT_FP, "errors_12-22-20.xls")

everything_df = pd.read_excel(NOT_ERRORS_FP)
errors_df = pd.read_excel(ERRORS_FP)

# %%
#inspect the string handles for all the different coding types
all_coding_types = everything_df["Hierarchical Name"].unique()
all_coding_types
# Out:
# array(['Nodes\\\\Event (Extent)', 'Nodes\\\\Event (Extent)\\Needs Review',
#        'Nodes\\\\Event (Initiating Question)',
#        'Nodes\\\\Event (Initiating Question)\\Needs Review',
#        'Nodes\\\\Narrative Type\\Needs Review',
#        'Nodes\\\\Narrative Type\\Observations and Cultural References',
#        'Nodes\\\\Narrative Type\\Personal Experience',
#        'Nodes\\\\Narrative Type\\Personal Experience\\Negative Response',
#        'Nodes\\\\Narrative Type\\Policy; Politics; Legal',
#        'Nodes\\\\Narrative Type\\Second-hand Account',
#        'Nodes\\\\Topic\\Interracial Event',
#        'Nodes\\\\Topic\\Needs Review',
#        'Nodes\\\\Topic\\Sexual assault or rape',
#        'Nodes\\\\Topic\\Sexual harassment'], dtype=object)

# %%
everything_df["Hierarchical Name"].value_counts()
# Out:
# Nodes\\Event (Extent)                                          1231
# Nodes\\Event (Initiating Question)                             1075
# Nodes\\Topic\Sexual assault or rape                             758
# Nodes\\Narrative Type\Policy; Politics; Legal                   504
# Nodes\\Narrative Type\Observations and Cultural References      386
# Nodes\\Narrative Type\Second-hand Account                       244
# Nodes\\Narrative Type\Personal Experience                       242
# Nodes\\Topic\Interracial Event                                  223
# Nodes\\Topic\Sexual harassment                                  202
# Nodes\\Narrative Type\Personal Experience\Negative Response      45
# Nodes\\Narrative Type\Needs Review                               27
# Nodes\\Event (Extent)\Needs Review                               23
# Nodes\\Topic\Needs Review                                        13
# Nodes\\Event (Initiating Question)\Needs Review                   9
# Name: Hierarchical Name, dtype: int64

# %%
#get everything coded as rape (i.e. the Hierarchical Name field is 'Nodes\\\\Topic\\Sexual assault or rape')
rape_events = everything_df[ everything_df['Hierarchical Name'] == 'Nodes\\\\Topic\\Sexual assault or rape']

# %%
#get counts of rape event by collection
rape_events["Folder Location"].value_counts()
# Out:
# Files\\HM                      436
# Files\\SCVF                    147
# Files\\UNCTWMS                  91
# Files\\BWOH                     26
# Files\\SCAARJ                   15
# Files\\SCAP                     10
# Files\\UNCSW                     8
# Files\\SCAL                      8
# Files\\SHSA                      5
# Files\\ROHA                      5
# Files\\SHSF                      2
# Files\\Missing OSS and SOOH      2
# Files\\BWSP                      2
# Files\\UNCGAS                    1
# Name: Folder Location, dtype: int64

# %%
list_of_interviews_with_rape_event
# Out:
# ['Files\\\\BWOH\\\\BWOH_Adair_Christia',
#  'Files\\\\BWOH\\\\BWOH_Aiken_Harper_Rucker',
#  'Files\\\\BWOH\\\\BWOH_Duster_Alfreda',
#  'Files\\\\BWOH\\\\BWOH_Edmonds_Florence',
#  'Files\\\\BWOH\\\\BWOH_Edwards_Lena',
#  'Files\\\\BWOH\\\\BWOH_Harrison_Pleasant',
#  'Files\\\\BWOH\\\\BWOH_Kelly_Hattie',
#  'Files\\\\BWOH\\\\BWOH_Kittrell_Flemmie',
#  'Files\\\\BWOH\\\\BWOH_Lancaster_Abna',
#  'Files\\\\BWOH\\\\BWOH_Moore_Audley',
#  'Files\\\\BWOH\\\\BWOH_Parks_Rosa',
#  'Files\\\\BWOH\\\\BWOH_Scott_Esther',
#  'Files\\\\BWOH\\\\BWOH_Smith_Julia',
#  'Files\\\\BWOH\\\\BWOH_Snowden_Muriel',
#  'Files\\\\BWOH\\\\BWOH_Stokes_Olivia',
#  'Files\\\\BWOH\\\\BWOH_Temple_Ruth',
#  'Files\\\\BWOH\\\\BWOH_Thomas_Constance',
#  'Files\\\\BWOH\\\\BWOH_Thompson_Era',
#  'Files\\\\BWSP\\\\BWSP_Palmer_Alison',
#  'Files\\\\BWSP\\\\BWSP_Ross_Hilary',
#  'Files\\\\HM\\\\HM_Aiyetoro_Adjoa',
#  'Files\\\\HM\\\\HM_Alexander_Ethel',
#  'Files\\\\HM\\\\HM_Allen_Billie',
#  'Files\\\\HM\\\\HM_Amaki_Amalia',
#  'Files\\\\HM\\\\HM_Angelou_Maya',
#  'Files\\\\HM\\\\HM_Apilado_Ruth',
#  'Files\\\\HM\\\\HM_Bacon_Gloria',
#  'Files\\\\HM\\\\HM_Baiocchi_Regina',
#  'Files\\\\HM\\\\HM_Bath_Patricia',
#  'Files\\\\HM\\\\HM_Benson_Olive',
#  'Files\\\\HM\\\\HM_Berger-Sweeney_Joanne',
#  'Files\\\\HM\\\\HM_Billingsley_Amy',
#  'Files\\\\HM\\\\HM_Billingsley_ReShonda',
#  'Files\\\\HM\\\\HM_Billops_Camille',
#  'Files\\\\HM\\\\HM_Bridgewater_Dee',
#  'Files\\\\HM\\\\HM_Britt_Donna',
#  'Files\\\\HM\\\\HM_Brock-Leftridge_Martha',
#  'Files\\\\HM\\\\HM_Brooks_Queen',
#  'Files\\\\HM\\\\HM_Brown_Jamie',
#  'Files\\\\HM\\\\HM_Brown_Yvette',
#  'Files\\\\HM\\\\HM_Bundles_A_Lelia',
#  'Files\\\\HM\\\\HM_Burton_Cheryl',
#  'Files\\\\HM\\\\HM_Butts_June',
#  'Files\\\\HM\\\\HM_Cantarella_Marcia',
#  'Files\\\\HM\\\\HM_Carrington_Arese',
#  'Files\\\\HM\\\\HM_Carwell_Hattie',
#  'Files\\\\HM\\\\HM_Chenzira_Ayoka',
#  'Files\\\\HM\\\\HM_Chew_Vivian',
#  'Files\\\\HM\\\\HM_Clarke_Caroline',
#  'Files\\\\HM\\\\HM_Cole_Brenda',
#  'Files\\\\HM\\\\HM_Copeland_Margot',
#  'Files\\\\HM\\\\HM_Cox_Marcella',
#  'Files\\\\HM\\\\HM_Cross_Dolores',
#  'Files\\\\HM\\\\HM_Cross_June',
#  'Files\\\\HM\\\\HM_Cunningham_Evelyn',
#  'Files\\\\HM\\\\HM_Daniel_Elnora',
#  'Files\\\\HM\\\\HM_Davis_Michaela',
#  'Files\\\\HM\\\\HM_Dawson_Lula',
#  'Files\\\\HM\\\\HM_DeCosta-Willis_Miriam',
#  'Files\\\\HM\\\\HM_Dee_Ruby',
#  'Files\\\\HM\\\\HM_Dellums_Leola',
#  'Files\\\\HM\\\\HM_Dickerson_Amina',
#  'Files\\\\HM\\\\HM_Dyson_Marcia',
#  'Files\\\\HM\\\\HM_Edwards_Audrey',
#  'Files\\\\HM\\\\HM_Estes_Sidmel',
#  'Files\\\\HM\\\\HM_Fairhurst_Norma',
#  'Files\\\\HM\\\\HM_Fales-Hill_Susan',
#  'Files\\\\HM\\\\HM_Farmer_Sharon',
#  'Files\\\\HM\\\\HM_Ferguson_Renee',
#  'Files\\\\HM\\\\HM_Fields_Dorothy',
#  'Files\\\\HM\\\\HM_Flake_Elaine',
#  'Files\\\\HM\\\\HM_Frazier_Frances',
#  'Files\\\\HM\\\\HM_Fry_Rita',
#  'Files\\\\HM\\\\HM_Gillespie_Marcia',
#  'Files\\\\HM\\\\HM_Giovanni_Nikki',
#  'Files\\\\HM\\\\HM_Glenn_Carolyn',
#  'Files\\\\HM\\\\HM_Grant_Jacquelyn',
#  'Files\\\\HM\\\\HM_Gray_Edith',
#  'Files\\\\HM\\\\HM_Grevious_Audrey',
#  'Files\\\\HM\\\\HM_Grimshaw_Jacquelyne',
#  'Files\\\\HM\\\\HM_Guidry_Carolyn',
#  'Files\\\\HM\\\\HM_Guy_Jasmine',
#  'Files\\\\HM\\\\HM_Haizlip_Shirlee',
#  'Files\\\\HM\\\\HM_Hall_Evangeline',
#  'Files\\\\HM\\\\HM_Hampshire-Cowan_Artis',
#  'Files\\\\HM\\\\HM_Hare_Julia',
#  'Files\\\\HM\\\\HM_Harris-Perry_Melissa',
#  'Files\\\\HM\\\\HM_Hines_Bea',
#  'Files\\\\HM\\\\HM_Hobson_Mellody',
#  'Files\\\\HM\\\\HM_Hughley_Stephanie',
#  'Files\\\\HM\\\\HM_Hunter_Karen',
#  'Files\\\\HM\\\\HM_Hunter-Gault_Charlayne',
#  'Files\\\\HM\\\\HM_Huntley_Lynn',
#  'Files\\\\HM\\\\HM_Hutcherson_Bernice',
#  'Files\\\\HM\\\\HM_Hutchinson_Janice',
#  'Files\\\\HM\\\\HM_Jackson_Teri',
#  'Files\\\\HM\\\\HM_Jackson_Valerie',
#  'Files\\\\HM\\\\HM_James-Brown_Christine',
#  'Files\\\\HM\\\\HM_Jefferson_Margo',
#  'Files\\\\HM\\\\HM_John_Bonnie',
#  'Files\\\\HM\\\\HM_Johnson_Bev',
#  'Files\\\\HM\\\\HM_Jones_Elaine',
#  'Files\\\\HM\\\\HM_Jones_Jennifer',
#  'Files\\\\HM\\\\HM_Key_Alice',
#  'Files\\\\HM\\\\HM_Lawson_Jennifer',
#  'Files\\\\HM\\\\HM_Lee_Barbara',
#  'Files\\\\HM\\\\HM_Lewis_Elma',
#  'Files\\\\HM\\\\HM_Love_Ruth',
#  'Files\\\\HM\\\\HM_Lowery_Evelyn',
#  'Files\\\\HM\\\\HM_Lundy_Carmen',
#  'Files\\\\HM\\\\HM_Lythcott_Marcia',
#  'Files\\\\HM\\\\HM_Madison_Paula',
#  'Files\\\\HM\\\\HM_Malveaux_Suzanne',
#  'Files\\\\HM\\\\HM_Massey_Shirley',
#  'Files\\\\HM\\\\HM_McCabe_Jewell',
#  'Files\\\\HM\\\\HM_McElroy_Marion',
#  'Files\\\\HM\\\\HM_McQueen_Armelia',
#  'Files\\\\HM\\\\HM_Michel_Harriet',
#  'Files\\\\HM\\\\HM_Miles_Steen',
#  'Files\\\\HM\\\\HM_Miller-Perry_Rosetta',
#  'Files\\\\HM\\\\HM_Mitchell_Mary',
#  'Files\\\\HM\\\\HM_Montes_Peggy',
#  'Files\\\\HM\\\\HM_Neisser_Winifred',
#  'Files\\\\HM\\\\HM_Nelson_Jill',
#  'Files\\\\HM\\\\HM_Newby-Alexander_Cassandra',
#  'Files\\\\HM\\\\HM_Newkirk_Pamela',
#  'Files\\\\HM\\\\HM_Nottage_Lynn',
#  'Files\\\\HM\\\\HM_O_Neal-McCray_Hellen',
#  'Files\\\\HM\\\\HM_Omilami_Elisabeth',
#  'Files\\\\HM\\\\HM_Palmer_Jorja',
#  'Files\\\\HM\\\\HM_Payne_Scherrie',
#  'Files\\\\HM\\\\HM_Peeples_Audrey',
#  'Files\\\\HM\\\\HM_Pennick_Aurie',
#  'Files\\\\HM\\\\HM_Perry_June',
#  'Files\\\\HM\\\\HM_Pindell_Howardena',
#  'Files\\\\HM\\\\HM_Pratt_Sharon',
#  'Files\\\\HM\\\\HM_Randall_Alice',
#  'Files\\\\HM\\\\HM_Ransby_Barbara',
#  'Files\\\\HM\\\\HM_Ray_Fay',
#  'Files\\\\HM\\\\HM_Reynolds_Barbara',
#  'Files\\\\HM\\\\HM_Rice_Constance_1',
#  'Files\\\\HM\\\\HM_Robinson_Cleo',
#  'Files\\\\HM\\\\HM_Rolark-Barnes_Denise',
#  'Files\\\\HM\\\\HM_Rookard_Gloria',
#  'Files\\\\HM\\\\HM_Sanchez_Sonia',
#  'Files\\\\HM\\\\HM_Sanford_Adelaide',
#  'Files\\\\HM\\\\HM_Sci_LaVerne',
#  'Files\\\\HM\\\\HM_Scott_Gloria',
#  'Files\\\\HM\\\\HM_Sears_Leah',
#  'Files\\\\HM\\\\HM_Shange_Ntozake',
#  'Files\\\\HM\\\\HM_Shipp_E.',
#  'Files\\\\HM\\\\HM_Shorter_Vera',
#  'Files\\\\HM\\\\HM_Simmons_Debra',
#  'Files\\\\HM\\\\HM_Simpson_Carole',
#  'Files\\\\HM\\\\HM_Sizemore_Barbara',
#  'Files\\\\HM\\\\HM_Smith_Bev',
#  'Files\\\\HM\\\\HM_Smith_Beverly',
#  'Files\\\\HM\\\\HM_Spann-Cooper_Melody',
#  'Files\\\\HM\\\\HM_Stevens_Rochelle',
#  'Files\\\\HM\\\\HM_Stewart_Monica',
#  'Files\\\\HM\\\\HM_Swarns_Rachel',
#  'Files\\\\HM\\\\HM_Tate_Alysia',
#  'Files\\\\HM\\\\HM_Thompson_Francesca',
#  'Files\\\\HM\\\\HM_Tillman_Dorothy',
#  'Files\\\\HM\\\\HM_Topsy-Elvord_Doris',
#  'Files\\\\HM\\\\HM_Trotter_Eunice',
#  'Files\\\\HM\\\\HM_Ward_Val',
#  'Files\\\\HM\\\\HM_Waters_Maxine',
#  'Files\\\\HM\\\\HM_Watson_Diane',
#  'Files\\\\HM\\\\HM_Wattleton_Alyce',
#  'Files\\\\HM\\\\HM_Wesley_Valerie',
#  'Files\\\\HM\\\\HM_Whigham_Carolyn',
#  'Files\\\\HM\\\\HM_Whipper_Lucille',
#  'Files\\\\HM\\\\HM_Williams_Terrie',
#  'Files\\\\HM\\\\HM_Wilson_Lucy',
#  'Files\\\\HM\\\\HM_Wilson_Mary',
#  'Files\\\\HM\\\\HM_Wilson_Robin',
#  'Files\\\\HM\\\\HM_Windom_Alice',
#  'Files\\\\HM\\\\HM_Wright-Pryor_Barbara',
#  'Files\\\\HM\\\\HM_Young_Carolyn',
#  'Files\\\\HM\\\\HM_Zollar_Jawole',
#  'Files\\\\Missing OSS and SOOH\\\\OSS_Anderson_Karen',
#  'Files\\\\Missing OSS and SOOH\\\\SOOH_Braunlich_Phyllis',
#  'Files\\\\ROHA\\\\ROHA_Godfrey_Nancy',
#  'Files\\\\ROHA\\\\ROHA_Mandel_Adrienne_2',
#  'Files\\\\ROHA\\\\ROHA_Spetgang_Tilly_2',
#  'Files\\\\ROHA\\\\ROHA_Taylor_Kathleen',
#  'Files\\\\ROHA\\\\ROHA_Thompson_Pearl',
#  'Files\\\\SCAARJ\\\\SCAARJ_Luke_Mary',
#  'Files\\\\SCAARJ\\\\SCAARJ_Masaki_Beckie',
#  'Files\\\\SCAARJ\\\\SCAARJ_Mingus_Mia',
#  'Files\\\\SCAARJ\\\\SCAARJ_Zia_Helen',
#  'Files\\\\SCAL\\\\SCAL_Ahrens_Lois',
#  'Files\\\\SCAL\\\\SCAL_Newman_Leslea',
#  'Files\\\\SCAL\\\\SCAL_Pincus_Jane',
#  'Files\\\\SCAL\\\\SCAL_Pogrebin_LettyCottin',
#  'Files\\\\SCAL\\\\SCAL_Pollet_Tiik',
#  'Files\\\\SCAL\\\\SCAL_Shelton_Christine',
#  'Files\\\\SCAP\\\\SCAP_Hazeltine_Glenna',
#  'Files\\\\SCAP\\\\SCAP_Kessler_Elizabeth',
#  'Files\\\\SCAP\\\\SCAP_King_Brandy',
#  'Files\\\\SCAP\\\\SCAP_LaBarbera_Jen',
#  'Files\\\\SCAP\\\\SCAP_McNulty_Molly',
#  'Files\\\\SCAP\\\\SCAP_Rothblum_Esther',
#  'Files\\\\SCAP\\\\SCAP_Wang_Kit',
#  'Files\\\\SCAP\\\\SCAP_Yahm_Elinor',
#  'Files\\\\SCVF\\\\SCVF_Acey_Katherine',
#  'Files\\\\SCVF\\\\SCVF_Alexander_Dolores',
#  'Files\\\\SCVF\\\\SCVF_Allison_Dorothy',
#  'Files\\\\SCVF\\\\SCVF_Allison_Dorothy_Vazquez_Carmen',
#  'Files\\\\SCVF\\\\SCVF_Apuzzo_Virginia',
#  'Files\\\\SCVF\\\\SCVF_Asetoyer_Charon',
#  'Files\\\\SCVF\\\\SCVF_Avery_Byllye',
#  'Files\\\\SCVF\\\\SCVF_Beal_Frances',
#  'Files\\\\SCVF\\\\SCVF_Berek_Judy',
#  'Files\\\\SCVF\\\\SCVF_Biren_Joan',
#  'Files\\\\SCVF\\\\SCVF_Diallo_Dazon_Dixon',
#  'Files\\\\SCVF\\\\SCVF_Frantz_Marge',
#  'Files\\\\SCVF\\\\SCVF_Fried_Marlene_Gerber',
#  'Files\\\\SCVF\\\\SCVF_Gould_Sara',
#  'Files\\\\SCVF\\\\SCVF_Henry_Fran',
#  'Files\\\\SCVF\\\\SCVF_Hollibaugh_Amber',
#  'Files\\\\SCVF\\\\SCVF_Kramer_Marian',
#  'Files\\\\SCVF\\\\SCVF_Moraga_Cherrie',
#  'Files\\\\SCVF\\\\SCVF_Morales_Rosario',
#  'Files\\\\SCVF\\\\SCVF_Nelson_Marjory',
#  'Files\\\\SCVF\\\\SCVF_Nussbaum_Karen',
#  'Files\\\\SCVF\\\\SCVF_Payne_Ladoris',
#  'Files\\\\SCVF\\\\SCVF_Pharr_Suzanne',
#  'Files\\\\SCVF\\\\SCVF_Ports_Suki',
#  'Files\\\\SCVF\\\\SCVF_Pratt_Minnie_Bruce',
#  'Files\\\\SCVF\\\\SCVF_Roma_Catherine',
#  'Files\\\\SCVF\\\\SCVF_Saika_Peggy',
#  'Files\\\\SCVF\\\\SCVF_Shelley_Martha',
#  'Files\\\\SCVF\\\\SCVF_Smith_Barbara',
#  'Files\\\\SCVF\\\\SCVF_Steinem_Gloria',
#  'Files\\\\SCVF\\\\SCVF_Thom_Mary',
#  'Files\\\\SCVF\\\\SCVF_Toure_Nkenge',
#  'Files\\\\SCVF\\\\SCVF_Vazquez_Carmen',
#  'Files\\\\SCVF\\\\SCVF_Ward_Wynona',
#  'Files\\\\SCVF\\\\SCVF_Winslow_Barbara',
#  'Files\\\\SHSA\\\\SHSA_Gartrell_Nanette',
#  'Files\\\\SHSA\\\\SHSA_Gianturco_Paola',
#  'Files\\\\SHSF\\\\SHSF_Kraemer_Helena',
#  'Files\\\\SHSF\\\\SHSF_Litt_Iris',
#  'Files\\\\UNCGAS\\\\UNCGAS_Knudsen_Betty_McAllister_Beth',
#  'Files\\\\UNCSW\\\\UNCSW_Ames_Jessie_Daniel',
#  'Files\\\\UNCSW\\\\UNCSW_Dabbs_Edith',
#  'Files\\\\UNCSW\\\\UNCSW_MacDougall_Margaret_McDow',
#  'Files\\\\UNCSW\\\\UNCSW_Murray_Pauli',
#  'Files\\\\UNCSW\\\\UNCSW_Ransdall_Hollace',
#  'Files\\\\UNCSW\\\\UNCSW_Seeman_Elizabeth',
#  'Files\\\\UNCSW\\\\UNCSW_Wright_Alice_Norwood_Spearman_2',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Barrett_Margaret_Bowers',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Basham_Janelle',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Bell_Brenda',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Davis_Catherine',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Elmore_Bessie',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Evans_Sara_M_(Sara_Margaret)',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Garcia_Serena',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Grant_Patricia',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Hatcher_Paris',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Herr_Mary',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Hutchison_Carolyn',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Leeper_Connie',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Levy_Dianne',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Parsons_Darlene',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Pevia_Kim_Adrienne',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Pharr_Suzanne',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Prior_Karen_Swallow',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Radcliff_Melissa',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Ray_Sylvia',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Reisman_Judith',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Renz_Constance_Anne',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Robinson_Gail',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Ross_Loretta',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Rostan_June',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Rovetti_Corinne_McNabb_Richard_McNabb_Bernadette',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Sassman_Susan',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Short_Joan_Boyd',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Sobieski_Wanda_2',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Stokes_Jeanette',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Stulberg_Dorothy',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Turner_Katherine',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Wilson_Gen',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Wolf_Paula',
#  'Files\\\\UNCTWMS\\\\UNCTWMS_Zalph_Ruth_Colish']

# %%
list_of_interviews_with_rape_event[0].split('\\\\')
# Out:
# ['Files', 'BWOH', 'BWOH_Adair_Christia']

# %%
#get counts of interviews that have at least one rape event, by collection
list_of_interviews_with_rape_event = list(rape_events["Hierarchical Name.1"].unique())

counts_by_collection = defaultdict(lambda:0)
for interview in list_of_interviews_with_rape_event:
    
    collection = interview.split('\\\\')[1]
    counts_by_collection[collection] += 1

# %%
counts_by_collection
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'BWOH': 18,
#              'BWSP': 2,
#              'HM': 161,
#              'Missing OSS and SOOH': 2,
#              'ROHA': 5,
#              'SCAARJ': 4,
#              'SCAL': 6,
#              'SCAP': 8,
#              'SCVF': 35,
#              'SHSA': 2,
#              'SHSF': 2,
#              'UNCGAS': 1,
#              'UNCSW': 7,
#              'UNCTWMS': 34})

# %%
'''
#manual counts of number of interviews in each collection, followed by description of how count was arrived at
#TODO: clean up organization of transcripts on google drive so we know how many
#interviews are in each collection and can easily get .txt files for them
total_interviews_per_collection = {
    #'BWOH': 18,
             #'BWSP': 2,
             'HM': 2687, #number of .txt files in download of HM transcripts from Google drive
             #'Missing OSS and SOOH': 2,
             #'ROHA': 5,
             #'SCAARJ': 4,
             #'SCAL': 6,
             #'SCAP': 8,
             'SCVF': 247, # UNCERTAIN, just comes from adding up counts of Smith college related interviews on Collection Info spreadsheet
             #'SHSA': 2,
             #'SHSF': 2,
             #'UNCGAS': 1,
             #'UNCSW': 7,
             #'UNCTWMS': 34}
}
'''

total_interviews_per_collection = dict(metadata['collection_id'].value_counts())

# %%
for key, val in counts_by_collection.items():
    if key in total_interviews_per_collection:
        percentage = counts_by_collection[key]/total_interviews_per_collection[key]
        print("{}: {:.3f}".format(key, percentage))
# Out:
# BWOH: 0.250
# BWSP: 0.012
# HM: 0.060
# ROHA: 0.062
# SCAARJ: 0.286
# SCAL: 0.400
# SCAP: 0.040
# SCVF: 0.686
# SHSA: 0.067
# SHSF: 0.043
# UNCGAS: 0.033
# UNCSW: 0.104
# UNCTWMS: 0.204
