# %%
import csv
import numpy as np
from collections import defaultdict
from matplotlib import pyplot
import pandas

# %%
BLANKS=["","RBNF1", "RBNF2", "RBNF", "0", "RBNF 1", "RBNF 2"]
#TOTAL= 5048
TOTAL=2734
#TOTAL=1351
#TOTAL=1201
#TOTAL=1168

# %%
def loadCsvData(fileName):
	matrix = []
	# open a file
	with open(fileName) as f:
		reader = csv.reader(f)

		# loop over each row in the file
		for row in reader:

			# cast each value to a float
			doubleRow = []
			for value in row:
				doubleRow.append(value.strip())

			# store the row into our matrix
			matrix.append(doubleRow)
	return matrix

# %%
def printData(matrix):
	for row in matrix:
		print (row)

# %%
data= loadCsvData("metadata.csv")

# %%
data=pandas.DataFrame(data[1:], columns=data[0])

# %%
database=defaultdict(lambda: defaultdict(lambda:0))
for i in range(len(data)):
    for atr in data.columns:
        if atr== "researcher_assumed_birth_decade":
            continue
        if atr== "researcher_assumed_race":
            continue
        value= data[atr][i]
        if value in BLANKS and atr=="birth_decade":
            value= data.loc[i, "researcher_assumed_birth_decade"]
        if value in BLANKS and atr=="identified_race":
            value= data.loc[i, "researcher_assumed_race"]
        database[i][atr]=value
print(database)
# Out:
# defaultdict(<function <lambda> at 0x7f8d62cf0ae8>, {0: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62cf0d08>, {'\ufeffbirth_decade': '1890', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Married (except if separated)', 'education': 'High school graduate', 'sex': 'Female'}), 1: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62cf0e18>, {'\ufeffbirth_decade': '1890', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Widowed', 'education': "Bachelor's degree", 'sex': 'Female'}), 2: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62cf0ea0>, {'\ufeffbirth_decade': '1900', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': '', 'education': 'Graduate or professional degree', 'sex': 'Female'}), 3: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62cf0f28>, {'\ufeffbirth_decade': '1890', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Divorced', 'education': "Associate's degree", 'sex': 'Female'}), 4: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62f04048>, {'\ufeffbirth_decade': '1890', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Married (except if separated)', 'education': "Bachelor's degree", 'sex': 'Female'}), 5: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62f040d0>, {'\ufeffbirth_decade': '1910', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Married (except if separated)', 'education': 'Graduate or professional degree', 'sex': 'Female'}), 6: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62f04158>, {'\ufeffbirth_decade': '1890', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Married (except if separated)', 'education': 'Graduate or professional degree', 'sex': 'Female'}), 7: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62f041e0>, {'\ufeffbirth_decade': '1900', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Married (except if separated)', 'education': 'High school graduate', 'sex': 'Female'}), 8: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62f04268>, {'\ufeffbirth_decade': '1900', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Widowed', 'education': "Bachelor's degree", 'sex': 'Female'}), 9: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62f042f0>, {'\ufeffbirth_decade': '1880', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': '', 'education': "Bachelor's degree", 'sex': 'Female'}), 10: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62f04378>, {'\ufeffbirth_decade': '1890', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Widowed', 'education': 'High school graduate', 'sex': 'Female'}), 11: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62f04400>, {'\ufeffbirth_decade': '1890', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Never married', 'education': 'Graduate or professional degree', 'sex': 'Female'}), 12: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62f04488>, {'\ufeffbirth_decade': '1900', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Widowed', 'education': "Associate's degree", 'sex': 'Female'}), 13: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62f04510>, {'\ufeffbirth_decade': '1900', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Widowed', 'education': 'Some college', 'sex': 'Female'}), 14: defaultdict(<function <lambda>.<locals>.<lambda> at 0x7f8d62f04598>, {'\ufeffbirth_decade': '1900', 'identified_race': 'Black or African American', 'marital_status_at_interview_time': 'Divorced', 'education': 'Some college', 'sex': 'Female'}), 15: defaultdict(< ...

# %%
dataformatted=defaultdict(lambda: defaultdict(lambda:0))
for i in database : 
    if database[i]["sex"]=="Male":
        continue
    for atr in database[i]:
        value= database[i][atr]
        if value not in BLANKS:
            dataformatted[atr][value]+=1
for cat in dataformatted:
    total=0
    for x in dataformatted[cat]:
        total+= dataformatted[cat][x]
    dataformatted[cat]["No Info"]= TOTAL-total

# %%
for table in dataformatted:
    for x,y in dataformatted[table].items():
        print("{}: {}".format(x,y))
        #print(x)
        #print(y)
# Out:
# 1890: 64
# 1900: 108
# 1910: 288
# 1880: 13
# 1930: 453
# 1870: 2
# 1940: 594
# 1920: 450
# 1950: 387
# 1980: 39
# 1960: 176
# 1970: 64
# 1990: 7
# 1970-1980: 1
# No Info: 88
# Black or African American: 1201
# White: 1351
# Asian: 42
# Hispanic/Latinx: 29
# Other Race: 5
# Two or More Races: 27
# Indigenous American or Alaska Native: 67
# No Info: 12
# Married (except if separated): 970
# Widowed: 247
# Divorced: 154
# Never married: 72
# Separated: 3
# Single: 52
# Domestic Partner: 1
# Common Law: 1
# No Info: 1234
# High school graduate: 205
# Bachelor's degree: 638
# Graduate or professional degree: 1168
# Associate's degree: 36
# Some college: 412
# 9th to 12th grade but no diploma: 114
# Less than 9th grade: 41
# No Info: 120
# Female: 2734
# No Info: 0
# 0: 2736
# No Info: -2

# %%
def checkAProfile(data, race, sex, education, birthdecade, exact):
    total=0
    attr=[("identified_race", race), ("sex", sex), ("education", education), ("\ufeffbirth_decade", birthdecade)]
    for i in data: 
        if exact:
            skip=False
            for a in attr:
                if data[i][a[0]] in BLANKS and a[1] != "":
                    skip=True
            if skip:
                continue
        skip=False   
        for a in attr:
            cat= data[i][a[0]]
            if a[1] != "" and cat not in BLANKS and cat != a[1]:
                skip=True
        if skip:
            continue
        total+=1
    return total

# %%
print(checkAProfile(database, "White", "Female", "Graduate or professional degree", "1940", True))
# Out:
# 160
